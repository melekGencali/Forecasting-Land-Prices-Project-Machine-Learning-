# %%
import pandas as pd
df_train = pd.read_csv('scrapyProje/Veri.csv', encoding = "UTF-8", sep=",")

# %%
def strip_col(x):
    if x.dtype == object:
        x = x.str.strip()
    return(x)

new = df_train.apply(strip_col)

# %%
df_train
# Out:
#              FIYAT         IL       ILCE         MAHALLE     ILAN_NO  \
# 0       165,000 TL  BalıkesIr    Ayvalık        Altınova  42916-1540
# 1       240,000 TL      Bursa  YenISehIr         Kozdere    69245-16
# 2     5,000,000 TL      NIGde     Merkez  AktaS (Devlet)   117875-28
# 3     6,848,000 TL      Adana     Ceyhan           Yalak  0-35832104
# 4       115,000 TL   Adıyaman      Kahta      CumhurIyet   118904-18
# ...            ...        ...        ...             ...         ...
# 7944    280,000 TL      NIGde     Merkez          Fertek   692268-96
# 7945  1,050,000 TL      Bursa     InegOl       KemalpaSa   114225-29
# 7946    630,000 TL     Burdur   GOlhIsar           Konak   114859-19
# 7947    750,000 TL      Bursa      IznIk         CICeklI   67015-262
# 7948  2,040,000 TL      IzmIr     DIkIlI         BahCelI   109447-79
#
#             ARSA_TIPI   METREKARE KREDIYE_UYGUNLUK      TAPU_DURUMU  TAKAS  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7949 entries, 0 to 7948
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FIYAT                  7949 non-null   object
#  1   IL                     7949 non-null   object
#  2   ILCE                   7949 non-null   object
#  3   MAHALLE                7949 non-null   object
#  4   ILAN_NO                7949 non-null   object
#  5   ARSA_TIPI              7949 non-null   object
#  6   METREKARE              7949 non-null   object
#  7   KREDIYE_UYGUNLUK       5030 non-null   object
#  8   TAPU_DURUMU            5831 non-null   object
#  9   TAKAS                  5402 non-null   object
#  10  KAT_KARSILIGI          7947 non-null   object
#  11  ILGILI_BELEDIYE        4824 non-null   object
#  12  METREKARE_BIRIM_FIYAT  2053 non-null   object
#  13  ADA                    2705 non-null   object
# ...

# %%
df_train["IL"] = df_train["IL"].str.upper()
df_train["ILCE"] = df_train["ILCE"].str.upper()
df_train["MAHALLE"] = df_train["MAHALLE"].str.upper()
df_train["TAPU_DURUMU"] = df_train["TAPU_DURUMU"].str.upper()
df_train["ARSA_TIPI"] = df_train["ARSA_TIPI"].str.upper()
df_train["ILGILI_BELEDIYE"] = df_train["ILGILI_BELEDIYE"].str.upper()
df_train["TAKAS"] = df_train["TAKAS"].str.upper()
df_train["KAT_KARSILIGI"] = df_train["KAT_KARSILIGI"].str.upper()
df_train["KREDIYE_UYGUNLUK"] = df_train["KREDIYE_UYGUNLUK"].str.upper()

# %%
# Target değeri Euro ve Dolar para birimi içerdiği için bu satırları dropladık
patternEUR = "EUR"
patternUSD = "USD"

USD = new['FIYAT'].str.contains(patternUSD)
USD_2 = new['KIRA_GETIRISI'].str.contains(patternUSD)
USD_3 = new['METREKARE_BIRIM_FIYAT'].str.contains(patternUSD)
EUR = new['FIYAT'].str.contains(patternEUR)
EUR_2 = new['KIRA_GETIRISI'].str.contains(patternEUR)
EUR_3 = new['METREKARE_BIRIM_FIYAT'].str.contains(patternEUR)

new = new[~USD]
new = new[~EUR]

# %%
import numpy as np
df_train = df_train.replace(to_replace='None', value=np.nan).dropna()

# %%
df_train.head(1000)
# Out:
#              FIYAT          IL         ILCE        MAHALLE     ILAN_NO  \
# 181     465,000 TL      ANKARA      GOLBASI          INCEK  113838-236
# 230   4,750,000 TL       IZMIR         URLA        DENIZLI   4079-1552
# 256      80,000 TL        USAK       ULUBEY          ASAGI   99661-261
# 261     700,000 TL      ELAZIG       MERKEZ  ABDULLAH PASA   91825-490
# 268     350,000 TL     DENIZLI    PAMUKKALE          AKKOY  109492-120
# ...            ...         ...          ...            ...         ...
# 7759    300,000 TL    TEKIRDAG       ERGENE         SAGLIK   116064-10
# 7826    595,000 TL      ANKARA      GOLBASI     KIZILCASAR   97196-257
# 7843    200,000 TL  KIRKLARELI  PEHLIVANKOY         AKARCA    116132-9
# 7933    225,000 TL      ANKARA       SINCAN   FEVZI CAKMAK   4384-6607
# 7940      1,111 TL      ANKARA  YENIMAHALLE     KARACAKAYA   116224-21
#
#             ARSA_TIPI  METREKARE KREDIYE_UYGUNLUK      TAPU_DURUMU  TAKAS  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 181 to 7940
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FIYAT                  193 non-null    object
#  1   IL                     193 non-null    object
#  2   ILCE                   193 non-null    object
#  3   MAHALLE                193 non-null    object
#  4   ILAN_NO                193 non-null    object
#  5   ARSA_TIPI              193 non-null    object
#  6   METREKARE              193 non-null    object
#  7   KREDIYE_UYGUNLUK       193 non-null    object
#  8   TAPU_DURUMU            193 non-null    object
#  9   TAKAS                  193 non-null    object
#  10  KAT_KARSILIGI          193 non-null    object
#  11  ILGILI_BELEDIYE        193 non-null    object
#  12  METREKARE_BIRIM_FIYAT  193 non-null    object
#  13  ADA                    193 non-null    object
# ...
